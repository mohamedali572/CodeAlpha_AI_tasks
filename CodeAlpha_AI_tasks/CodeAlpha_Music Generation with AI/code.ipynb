# %%
import glob
import pickle
import numpy as np
from music21 import converter, instrument, note, chord
import warnings

warnings.filterwarnings("ignore", category=UserWarning)

def load_midi_files():
    notes = []
    midi_files = glob.glob("data/**/*.mid", recursive=True)

    if not midi_files:
        print("⚠ No MIDI files found in 'data/' folder.")
        return []

    print(f"Found {len(midi_files)} MIDI files. Starting processing...\n")

    for idx, file in enumerate(midi_files, start=1):
        print(f"[{idx}/{len(midi_files)}] Processing: {file}")

        try:
            midi = converter.parse(file)
            parts = instrument.partitionByInstrument(midi)
            elements = parts.parts[0].recurse() if parts else midi.flat.notes

            for element in elements:
                if isinstance(element, note.Note):
                    notes.append(str(element.pitch))
                elif isinstance(element, chord.Chord):
                    notes.append('.'.join(str(n) for n in element.normalOrder))
        except Exception as e:
            print(f"⚠ Error processing {file}: {e}")

    with open("data/notes.pkl", "wb") as f:
        pickle.dump(notes, f)

    print(f"\nProcessing complete! Total notes collected: {len(notes)}")
    return notes

def prepare_sequences(notes, seq_length=100):
    pitchnames = sorted(set(notes))
    note_to_int = {note: num for num, note in enumerate(pitchnames)}

    network_input = []
    network_output = []

    for i in range(len(notes) - seq_length):
        seq_in = notes[i:i + seq_length]
        seq_out = notes[i + seq_length]
        network_input.append([note_to_int[n] for n in seq_in])
        network_output.append(note_to_int[seq_out])

    n_patterns = len(network_input)
    input_tensor = np.reshape(network_input, (n_patterns, seq_length, 1)) / float(len(pitchnames))
    output_tensor = np.array(network_output)

    return input_tensor, output_tensor, note_to_int, pitchnames

if __name__ == "__main__":
    notes = load_midi_files()
    print("Preprocessing completed. You can now run train.py")
# Out:
# Found 295 MIDI files. Starting processing...
#
# [1/295] Processing: data\albeniz\alb_esp1.mid
# [2/295] Processing: data\albeniz\alb_esp2.mid
# [3/295] Processing: data\albeniz\alb_esp3.mid
# [4/295] Processing: data\albeniz\alb_esp4.mid
# [5/295] Processing: data\albeniz\alb_esp5.mid
# [6/295] Processing: data\albeniz\alb_esp6.mid
# [7/295] Processing: data\albeniz\alb_se1.mid
# [8/295] Processing: data\albeniz\alb_se2.mid
# [9/295] Processing: data\albeniz\alb_se3.mid
# [10/295] Processing: data\albeniz\alb_se4.mid
# [11/295] Processing: data\albeniz\alb_se5.mid
# [12/295] Processing: data\albeniz\alb_se6.mid
# [13/295] Processing: data\albeniz\alb_se7.mid
# [14/295] Processing: data\albeniz\alb_se8.mid
# [15/295] Processing: data\bach\bach_846.mid
# [16/295] Processing: data\bach\bach_847.mid
# [17/295] Processing: data\bach\bach_850.mid
# [18/295] Processing: data\balakir\islamei.mid
# [19/295] Processing: data\beeth\appass_1.mid
# [20/295] Processing: data\beeth\appass_2.mid
# [21/295] Processing: data\beeth\appass_3.mid
# [22/295] Processing: data\beeth\beethoven_hammerklavier_1.mid
# [23/295] Processing: data\beeth\beethoven_hammerklavier_2.mid
# [24/295] Processing: data\beeth\beethoven_hammerklavier_3.mid
# [25/295] Processing: data\beeth\beethoven_hammerklavier_4.mid
# [26/295] Processing: data\beeth\beethoven_les_adieux_1.mid
# [27/295] Processing: data\beeth\beethoven_les_adieux_2.mid
# [28/295] Processing: data\beeth\beethoven_les_adieux_3.mid
# [29/295] Processing: data\beeth\beethoven_opus10_1.mid
# [30/295] Processing: data\beeth\beethoven_opus10_2.mid
# [31/295] Processing: data\beeth\beethoven_opus10_3.mid
# [32/295] Processing: data\beeth\beethoven_opus22_1.mid
# [33/295] Processing: data\beeth\beethoven_opus22_2.mid
# [34/295] Processing: data\beeth\beethoven_opus22_3.mid
# [35/295] Processing: data\beeth\beethoven_opus22_4.mid
# [36/295] Processing: data\beeth\beethoven_opus90_1.mid
# [37/295] Processing: data\beeth\beethoven_opus90_2.mid
# [38/295] Processing: data\beeth\elise.mid
# [39/295] Processing: data\beeth\mond_1.mid
# [40/295] Processing: data\beeth\mond_2.mid
# [41/295] Processing: data\beeth\mond_3.mid
# [42/295] Processing: data\beeth\pathetique_1.mid
# [43/295] Processing: data\beeth\pathetique_2.mid
# [44/295] Processing: data\beeth\pathetique_3.mid
# [45/295] Processing: data\beeth\waldstein_1.mid
# [46/295] Processing: data\beeth\waldstein_2.mid
# [47/295] Processing: data\beeth\waldstein_3.mid
# [48/295] Processing: data\borodin\bor_ps1.mid
# [49/295] Processing: data\borodin\bor_ps2.mid
# [50/295] Processing: data\borodin\bor_ps3.mid
# [51/295] Processing: data\borodin\bor_ps4.mid
# [52/295] Processing: data\borodin\bor_ps5.mid
# [53/295] Processing: data\borodin\bor_ps6.mid
# [54/295] Processing: data\borodin\bor_ps7.mid
# [55/295] Processing: data\brahms\brahms_opus117_1.mid
# [56/295] Processing: data\brahms\brahms_opus117_2.mid
# [57/295] Processing: data\brahms\brahms_opus1_1.mid
# [58/295] Processing: data\brahms\brahms_opus1_2.mid
# [59/295] Processing: data\brahms\brahms_opus1_3.mid
# [60/295] Processing: data\brahms\brahms_opus1_4.mid
# [61/295] Processing: data\brahms\br_im2.mid
# [62/295] Processing: data\brahms\br_im5.mid
# [63/295] Processing: data\brahms\BR_IM6.MID
# [64/295] Processing: data\brahms\br_rhap.mid
# [65/295] Processing: data\burgm\burg_agitato.mid
# [66/295] Processing: data\burgm\burg_erwachen.mid
# [67/295] Processing: data\burgm\burg_geschwindigkeit.mid
# [68/295] Processing: data\burgm\burg_gewitter.mid
# [69/295] Processing: data\burgm\burg_perlen.mid
# [70/295] Processing: data\burgm\burg_quelle.mid
# [71/295] Processing: data\burgm\burg_spinnerlied.mid
# [72/295] Processing: data\burgm\burg_sylphen.mid
# [73/295] Processing: data\burgm\burg_trennung.mid
# [74/295] Processing: data\chopin\chpn-p1.mid
# [75/295] Processing: data\chopin\chpn-p10.mid
# [76/295] Processing: data\chopin\chpn-p11.mid
# [77/295] Processing: data\chopin\chpn-p12.mid
# [78/295] Processing: data\chopin\chpn-p13.mid
# [79/295] Processing: data\chopin\chpn-p14.mid
# [80/295] Processing: data\chopin\chpn-p15.mid
# [81/295] Processing: data\chopin\chpn-p16.mid
# [82/295] Processing: data\chopin\chpn-p17.mid
# [83/295] Processing: data\chopin\chpn-p18.mid
# [84/295] Processing: data\chopin\chpn-p19.mid
# [85/295] Processing: data\chopin\chpn-p2.mid
# [86/295] Processing: data\chopin\chpn-p20.mid
# [87/295] Processing: data\chopin\chpn-p21.mid
# [88/295] Processing: data\chopin\chpn-p22.mid
# [89/295] Processing: data\chopin\chpn-p23.mid
# [90/295] Processing: data\chopin\chpn-p24.mid
# [91/295] Processing: data\chopin\chpn-p3.mid
# [92/295] Processing: data\chopin\chpn-p4.mid
# [93/295] Processing: data\chopin\chpn-p5.mid
# [94/295] Processing: data\chopin\chpn-p6.mid
# [95/295] Processing: data\chopin\chpn-p7.mid
# [96/295] Processing: data\chopin\chpn-p8.mid
# [97/295] Processing: data\chopin\chpn-p9.mid
# [98/295] Processing: data\chopin\chpn_op10_e01.mid
# [99/295] Processing: data\chopin\chpn_op10_e05.mid
# [100/295] Processing: data\chopin\chpn_op10_e12.mid
# [101/295] Processing: data\chopin\chpn_op23.mid
# [102/295] Processing: data\chopin\chpn_op25_e1.mid
# [103/295] Processing: data\chopin\chpn_op25_e11.mid
# [104/295] Processing: data\chopin\chpn_op25_e12.mid
# [105/295] Processing: data\chopin\chpn_op25_e2.mid
# [106/295] Processing: data\chopin\chpn_op25_e3.mid
# [107/295] Processing: data\chopin\chpn_op25_e4.mid
# [108/295] Processing: data\chopin\chpn_op27_1.mid
# [109/295] Processing: data\chopin\chpn_op27_2.mid
# [110/295] Processing: data\chopin\chpn_op33_2.mid
# [111/295] Processing: data\chopin\chpn_op33_4.mid
# [112/295] Processing: data\chopin\chpn_op35_1.mid
# [113/295] Processing: data\chopin\chpn_op35_2.mid
# [114/295] Processing: data\chopin\chpn_op35_3.mid
# [115/295] Processing: data\chopin\chpn_op35_4.mid
# [116/295] Processing: data\chopin\chpn_op53.mid
# [117/295] Processing: data\chopin\chpn_op66.mid
# [118/295] Processing: data\chopin\chpn_op7_1.mid
# [119/295] Processing: data\chopin\chpn_op7_2.mid
# [120/295] Processing: data\chopin\chp_op18.mid
# [121/295] Processing: data\chopin\chp_op31.mid
# [122/295] Processing: data\debussy\debussy_cc_1.mid
# [123/295] Processing: data\debussy\debussy_cc_2.mid
# [124/295] Processing: data\debussy\debussy_cc_3.mid
# [125/295] Processing: data\debussy\debussy_cc_4.mid
# [126/295] Processing: data\debussy\debussy_cc_6.mid
# [127/295] Processing: data\debussy\DEB_CLAI.MID
# [128/295] Processing: data\debussy\deb_menu.mid
# [129/295] Processing: data\debussy\DEB_PASS.MID
# [130/295] Processing: data\debussy\deb_prel.mid
# [131/295] Processing: data\granados\gra_esp_2.mid
# [132/295] Processing: data\granados\gra_esp_3.mid
# [133/295] Processing: data\granados\gra_esp_4.mid
# [134/295] Processing: data\grieg\grieg_album.mid
# [135/295] Processing: data\grieg\grieg_berceuse.mid
# [136/295] Processing: data\grieg\grieg_brooklet.mid
# [137/295] Processing: data\grieg\grieg_butterfly.mid
# [138/295] Processing: data\grieg\grieg_elfentanz.mid
# [139/295] Processing: data\grieg\grieg_halling.mid
# [140/295] Processing: data\grieg\grieg_kobold.mid
# [141/295] Processing: data\grieg\grieg_march.mid
# [142/295] Processing: data\grieg\grieg_once_upon_a_time.mid
# [143/295] Processing: data\grieg\grieg_spring.mid
# [144/295] Processing: data\grieg\grieg_voeglein.mid
# [145/295] Processing: data\grieg\grieg_waechter.mid
# [146/295] Processing: data\grieg\grieg_walzer.mid
# [147/295] Processing: data\grieg\grieg_wanderer.mid
# [148/295] Processing: data\grieg\grieg_wedding.mid
# [149/295] Processing: data\grieg\grieg_zwerge.mid
# [150/295] Processing: data\haydn\haydn_33_1.mid
# [151/295] Processing: data\haydn\haydn_33_2.mid
# [152/295] Processing: data\haydn\haydn_33_3.mid
# [153/295] Processing: data\haydn\haydn_35_1.mid
# [154/295] Processing: data\haydn\haydn_35_2.mid
# [155/295] Processing: data\haydn\haydn_35_3.mid
# [156/295] Processing: data\haydn\haydn_43_1.mid
# [157/295] Processing: data\haydn\haydn_43_2.mid
# [158/295] Processing: data\haydn\haydn_43_3.mid
# [159/295] Processing: data\haydn\haydn_7_1.mid
# [160/295] Processing: data\haydn\haydn_7_2.mid
# [161/295] Processing: data\haydn\haydn_7_3.mid
# [162/295] Processing: data\haydn\haydn_8_1.mid
# [163/295] Processing: data\haydn\haydn_8_2.mid
# [164/295] Processing: data\haydn\haydn_8_3.mid
# [165/295] Processing: data\haydn\haydn_8_4.mid
# [166/295] Processing: data\haydn\haydn_9_1.mid
# [167/295] Processing: data\haydn\haydn_9_2.mid
# [168/295] Processing: data\haydn\haydn_9_3.mid
# [169/295] Processing: data\haydn\hay_40_1.mid
# [170/295] Processing: data\haydn\hay_40_2.mid
# [171/295] Processing: data\liszt\liz_donjuan.mid
# [172/295] Processing: data\liszt\liz_et1.mid
# [173/295] Processing: data\liszt\liz_et2.mid
# [174/295] Processing: data\liszt\liz_et3.mid
# [175/295] Processing: data\liszt\liz_et4.mid
# [176/295] Processing: data\liszt\liz_et5.mid
# [177/295] Processing: data\liszt\liz_et6.mid
# [178/295] Processing: data\liszt\liz_et_trans4.mid
# [179/295] Processing: data\liszt\liz_et_trans5.mid
# [180/295] Processing: data\liszt\liz_et_trans8.mid
# [181/295] Processing: data\liszt\liz_liebestraum.mid
# [182/295] Processing: data\liszt\liz_rhap02.mid
# [183/295] Processing: data\liszt\liz_rhap09.mid
# [184/295] Processing: data\liszt\liz_rhap10.mid
# [185/295] Processing: data\liszt\liz_rhap12.mid
# [186/295] Processing: data\liszt\liz_rhap15.mid
# [187/295] Processing: data\mendelssohn\mendel_op19_1.mid
# [188/295] Processing: data\mendelssohn\mendel_op19_2.mid
# [189/295] Processing: data\mendelssohn\mendel_op19_3.mid
# [190/295] Processing: data\mendelssohn\mendel_op19_4.mid
# [191/295] Processing: data\mendelssohn\mendel_op19_5.mid
# [192/295] Processing: data\mendelssohn\mendel_op19_6.mid
# [193/295] Processing: data\mendelssohn\mendel_op30_1.mid
# [194/295] Processing: data\mendelssohn\mendel_op30_2.mid
# [195/295] Processing: data\mendelssohn\mendel_op30_3.mid
# [196/295] Processing: data\mendelssohn\mendel_op30_4.mid
# [197/295] Processing: data\mendelssohn\mendel_op30_5.mid
# [198/295] Processing: data\mendelssohn\mendel_op53_5.mid
# [199/295] Processing: data\mendelssohn\mendel_op62_3.mid
# [200/295] Processing: data\mendelssohn\mendel_op62_4.mid
# [201/295] Processing: data\mendelssohn\mendel_op62_5.mid
# [202/295] Processing: data\mozart\mz_311_1.mid
# [203/295] Processing: data\mozart\mz_311_2.mid
# [204/295] Processing: data\mozart\mz_311_3.mid
# [205/295] Processing: data\mozart\mz_330_1.mid
# [206/295] Processing: data\mozart\mz_330_2.mid
# [207/295] Processing: data\mozart\mz_330_3.mid
# [208/295] Processing: data\mozart\mz_331_1.mid
# [209/295] Processing: data\mozart\mz_331_2.mid
# [210/295] Processing: data\mozart\mz_331_3.mid
# [211/295] Processing: data\mozart\mz_332_1.mid
# [212/295] Processing: data\mozart\mz_332_2.mid
# [213/295] Processing: data\mozart\mz_332_3.mid
# [214/295] Processing: data\mozart\mz_333_1.mid
# [215/295] Processing: data\mozart\mz_333_2.mid
# [216/295] Processing: data\mozart\mz_333_3.mid
# [217/295] Processing: data\mozart\mz_545_1.mid
# [218/295] Processing: data\mozart\mz_545_2.mid
# [219/295] Processing: data\mozart\mz_545_3.mid
# [220/295] Processing: data\mozart\mz_570_1.mid
# [221/295] Processing: data\mozart\mz_570_2.mid
# [222/295] Processing: data\mozart\mz_570_3.mid
# [223/295] Processing: data\muss\muss_1.mid
# [224/295] Processing: data\muss\muss_2.mid
# [225/295] Processing: data\muss\muss_3.mid
# [226/295] Processing: data\muss\muss_4.mid
# [227/295] Processing: data\muss\muss_5.mid
# [228/295] Processing: data\muss\muss_6.mid
# [229/295] Processing: data\muss\muss_7.mid
# [230/295] Processing: data\muss\muss_8.mid
# [231/295] Processing: data\schubert\schubert_D850_1.mid
# [232/295] Processing: data\schubert\schubert_D850_2.mid
# [233/295] Processing: data\schubert\schubert_D850_3.mid
# [234/295] Processing: data\schubert\schubert_D850_4.mid
# [235/295] Processing: data\schubert\schubert_D935_1.mid
# [236/295] Processing: data\schubert\schubert_D935_2.mid
# [237/295] Processing: data\schubert\schubert_D935_3.mid
# [238/295] Processing: data\schubert\schubert_D935_4.mid
# [239/295] Processing: data\schubert\schub_d760_1.mid
# [240/295] Processing: data\schubert\schub_d760_2.mid
# [241/295] Processing: data\schubert\schub_d760_3.mid
# [242/295] Processing: data\schubert\schub_d760_4.mid
# [243/295] Processing: data\schubert\schub_d960_1.mid
# [244/295] Processing: data\schubert\schub_d960_2.mid
# [245/295] Processing: data\schubert\schub_d960_3.mid
# [246/295] Processing: data\schubert\schub_d960_4.mid
# [247/295] Processing: data\schubert\schuim-1.mid
# [248/295] Processing: data\schubert\schuim-2.mid
# [249/295] Processing: data\schubert\schuim-3.mid
# [250/295] Processing: data\schubert\schuim-4.mid
# [251/295] Processing: data\schubert\schumm-1.mid
# [252/295] Processing: data\schubert\schumm-2.mid
# [253/295] Processing: data\schubert\schumm-3.mid
# [254/295] Processing: data\schubert\schumm-4.mid
# [255/295] Processing: data\schubert\schumm-5.mid
# [256/295] Processing: data\schubert\schumm-6.mid
# [257/295] Processing: data\schubert\schu_143_1.mid
# [258/295] Processing: data\schubert\schu_143_2.mid
# [259/295] Processing: data\schubert\schu_143_3.mid
# [260/295] Processing: data\schumann\schum_abegg.mid
# [261/295] Processing: data\schumann\scn15_1.mid
# [262/295] Processing: data\schumann\scn15_10.mid
# [263/295] Processing: data\schumann\scn15_11.mid
# [264/295] Processing: data\schumann\scn15_12.mid
# [265/295] Processing: data\schumann\scn15_13.mid
# [266/295] Processing: data\schumann\scn15_2.mid
# [267/295] Processing: data\schumann\scn15_3.mid
# [268/295] Processing: data\schumann\scn15_4.mid
# [269/295] Processing: data\schumann\scn15_5.mid
# [270/295] Processing: data\schumann\scn15_6.mid
# [271/295] Processing: data\schumann\scn15_7.mid
# [272/295] Processing: data\schumann\scn15_8.mid
# [273/295] Processing: data\schumann\scn15_9.mid
# [274/295] Processing: data\schumann\scn16_1.mid
# [275/295] Processing: data\schumann\scn16_2.mid
# [276/295] Processing: data\schumann\scn16_3.mid
# [277/295] Processing: data\schumann\scn16_4.mid
# [278/295] Processing: data\schumann\scn16_5.mid
# [279/295] Processing: data\schumann\scn16_6.mid
# [280/295] Processing: data\schumann\scn16_7.mid
# [281/295] Processing: data\schumann\scn16_8.mid
# [282/295] Processing: data\schumann\scn68_10.mid
# [283/295] Processing: data\schumann\scn68_12.mid
# [284/295] Processing: data\tschai\ty_april.mid
# [285/295] Processing: data\tschai\ty_august.mid
# [286/295] Processing: data\tschai\ty_dezember.mid
# [287/295] Processing: data\tschai\ty_februar.mid
# [288/295] Processing: data\tschai\ty_januar.mid
# [289/295] Processing: data\tschai\ty_juli.mid
# [290/295] Processing: data\tschai\ty_juni.mid
# [291/295] Processing: data\tschai\ty_maerz.mid
# [292/295] Processing: data\tschai\ty_mai.mid
# [293/295] Processing: data\tschai\ty_november.mid
# [294/295] Processing: data\tschai\ty_oktober.mid
# [295/295] Processing: data\tschai\ty_september.mid
#
# Processing complete! Total notes collected: 11362
# Preprocessing completed. You can now run train.py

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import pickle
# from preprocess import load_midi_files, prepare_sequences

# LSTM Model
class MusicLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(MusicLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])  # Last time-step
        return out

# Prepare data
notes = load_midi_files()
input_data, output_data, note_to_int, pitchnames = prepare_sequences(notes)

# Convert to Torch tensors
X = torch.tensor(input_data, dtype=torch.float32)
y = torch.tensor(output_data, dtype=torch.long)

dataset = TensorDataset(X, y)
loader = DataLoader(dataset, batch_size=64, shuffle=True)

# Model params
input_size = 1
hidden_size = 256
output_size = len(pitchnames)

model = MusicLSTM(input_size, hidden_size, output_size)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
epochs = 50
for epoch in range(epochs):
    total_loss = 0
    for batch_X, batch_y in loader:
        optimizer.zero_grad()
        output = model(batch_X)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss/len(loader):.4f}")

# Save model + mappings
torch.save(model.state_dict(), "model.pth")
with open("data/mappings.pkl", "wb") as f:
    pickle.dump((note_to_int, pitchnames), f)
# Out:
# Found 295 MIDI files. Starting processing...
#
# [1/295] Processing: data\albeniz\alb_esp1.mid
# [2/295] Processing: data\albeniz\alb_esp2.mid
# [3/295] Processing: data\albeniz\alb_esp3.mid
# [4/295] Processing: data\albeniz\alb_esp4.mid
# [5/295] Processing: data\albeniz\alb_esp5.mid
# [6/295] Processing: data\albeniz\alb_esp6.mid
# [7/295] Processing: data\albeniz\alb_se1.mid
# [8/295] Processing: data\albeniz\alb_se2.mid
# [9/295] Processing: data\albeniz\alb_se3.mid
# [10/295] Processing: data\albeniz\alb_se4.mid
# [11/295] Processing: data\albeniz\alb_se5.mid
# [12/295] Processing: data\albeniz\alb_se6.mid
# [13/295] Processing: data\albeniz\alb_se7.mid
# [14/295] Processing: data\albeniz\alb_se8.mid
# [15/295] Processing: data\bach\bach_846.mid
# [16/295] Processing: data\bach\bach_847.mid
# [17/295] Processing: data\bach\bach_850.mid
# [18/295] Processing: data\balakir\islamei.mid
# [19/295] Processing: data\beeth\appass_1.mid
# [20/295] Processing: data\beeth\appass_2.mid
# [21/295] Processing: data\beeth\appass_3.mid
# [22/295] Processing: data\beeth\beethoven_hammerklavier_1.mid
# [23/295] Processing: data\beeth\beethoven_hammerklavier_2.mid
# [24/295] Processing: data\beeth\beethoven_hammerklavier_3.mid
# [25/295] Processing: data\beeth\beethoven_hammerklavier_4.mid
# [26/295] Processing: data\beeth\beethoven_les_adieux_1.mid
# [27/295] Processing: data\beeth\beethoven_les_adieux_2.mid
# [28/295] Processing: data\beeth\beethoven_les_adieux_3.mid
# [29/295] Processing: data\beeth\beethoven_opus10_1.mid
# [30/295] Processing: data\beeth\beethoven_opus10_2.mid
# [31/295] Processing: data\beeth\beethoven_opus10_3.mid
# [32/295] Processing: data\beeth\beethoven_opus22_1.mid
# [33/295] Processing: data\beeth\beethoven_opus22_2.mid
# [34/295] Processing: data\beeth\beethoven_opus22_3.mid
# [35/295] Processing: data\beeth\beethoven_opus22_4.mid
# [36/295] Processing: data\beeth\beethoven_opus90_1.mid
# [37/295] Processing: data\beeth\beethoven_opus90_2.mid
# [38/295] Processing: data\beeth\elise.mid
# [39/295] Processing: data\beeth\mond_1.mid
# [40/295] Processing: data\beeth\mond_2.mid
# [41/295] Processing: data\beeth\mond_3.mid
# [42/295] Processing: data\beeth\pathetique_1.mid
# [43/295] Processing: data\beeth\pathetique_2.mid
# [44/295] Processing: data\beeth\pathetique_3.mid
# [45/295] Processing: data\beeth\waldstein_1.mid
# [46/295] Processing: data\beeth\waldstein_2.mid
# [47/295] Processing: data\beeth\waldstein_3.mid
# [48/295] Processing: data\borodin\bor_ps1.mid
# [49/295] Processing: data\borodin\bor_ps2.mid
# [50/295] Processing: data\borodin\bor_ps3.mid
# [51/295] Processing: data\borodin\bor_ps4.mid
# [52/295] Processing: data\borodin\bor_ps5.mid
# [53/295] Processing: data\borodin\bor_ps6.mid
# [54/295] Processing: data\borodin\bor_ps7.mid
# [55/295] Processing: data\brahms\brahms_opus117_1.mid
# [56/295] Processing: data\brahms\brahms_opus117_2.mid
# [57/295] Processing: data\brahms\brahms_opus1_1.mid
# [58/295] Processing: data\brahms\brahms_opus1_2.mid
# [59/295] Processing: data\brahms\brahms_opus1_3.mid
# [60/295] Processing: data\brahms\brahms_opus1_4.mid
# [61/295] Processing: data\brahms\br_im2.mid
# [62/295] Processing: data\brahms\br_im5.mid
# [63/295] Processing: data\brahms\BR_IM6.MID
# [64/295] Processing: data\brahms\br_rhap.mid
# [65/295] Processing: data\burgm\burg_agitato.mid
# [66/295] Processing: data\burgm\burg_erwachen.mid
# [67/295] Processing: data\burgm\burg_geschwindigkeit.mid
# [68/295] Processing: data\burgm\burg_gewitter.mid
# [69/295] Processing: data\burgm\burg_perlen.mid
# [70/295] Processing: data\burgm\burg_quelle.mid
# [71/295] Processing: data\burgm\burg_spinnerlied.mid
# [72/295] Processing: data\burgm\burg_sylphen.mid
# [73/295] Processing: data\burgm\burg_trennung.mid
# [74/295] Processing: data\chopin\chpn-p1.mid
# [75/295] Processing: data\chopin\chpn-p10.mid
# [76/295] Processing: data\chopin\chpn-p11.mid
# [77/295] Processing: data\chopin\chpn-p12.mid
# [78/295] Processing: data\chopin\chpn-p13.mid
# [79/295] Processing: data\chopin\chpn-p14.mid
# [80/295] Processing: data\chopin\chpn-p15.mid
# [81/295] Processing: data\chopin\chpn-p16.mid
# [82/295] Processing: data\chopin\chpn-p17.mid
# [83/295] Processing: data\chopin\chpn-p18.mid
# [84/295] Processing: data\chopin\chpn-p19.mid
# [85/295] Processing: data\chopin\chpn-p2.mid
# [86/295] Processing: data\chopin\chpn-p20.mid
# [87/295] Processing: data\chopin\chpn-p21.mid
# [88/295] Processing: data\chopin\chpn-p22.mid
# [89/295] Processing: data\chopin\chpn-p23.mid
# [90/295] Processing: data\chopin\chpn-p24.mid
# [91/295] Processing: data\chopin\chpn-p3.mid
# [92/295] Processing: data\chopin\chpn-p4.mid
# [93/295] Processing: data\chopin\chpn-p5.mid
# [94/295] Processing: data\chopin\chpn-p6.mid
# [95/295] Processing: data\chopin\chpn-p7.mid
# [96/295] Processing: data\chopin\chpn-p8.mid
# [97/295] Processing: data\chopin\chpn-p9.mid
# [98/295] Processing: data\chopin\chpn_op10_e01.mid
# [99/295] Processing: data\chopin\chpn_op10_e05.mid
# [100/295] Processing: data\chopin\chpn_op10_e12.mid
# [101/295] Processing: data\chopin\chpn_op23.mid
# [102/295] Processing: data\chopin\chpn_op25_e1.mid
# [103/295] Processing: data\chopin\chpn_op25_e11.mid
# [104/295] Processing: data\chopin\chpn_op25_e12.mid
# [105/295] Processing: data\chopin\chpn_op25_e2.mid
# [106/295] Processing: data\chopin\chpn_op25_e3.mid
# [107/295] Processing: data\chopin\chpn_op25_e4.mid
# [108/295] Processing: data\chopin\chpn_op27_1.mid
# [109/295] Processing: data\chopin\chpn_op27_2.mid
# [110/295] Processing: data\chopin\chpn_op33_2.mid
# [111/295] Processing: data\chopin\chpn_op33_4.mid
# [112/295] Processing: data\chopin\chpn_op35_1.mid
# [113/295] Processing: data\chopin\chpn_op35_2.mid
# [114/295] Processing: data\chopin\chpn_op35_3.mid
# [115/295] Processing: data\chopin\chpn_op35_4.mid
# [116/295] Processing: data\chopin\chpn_op53.mid
# [117/295] Processing: data\chopin\chpn_op66.mid
# [118/295] Processing: data\chopin\chpn_op7_1.mid
# [119/295] Processing: data\chopin\chpn_op7_2.mid
# [120/295] Processing: data\chopin\chp_op18.mid
# [121/295] Processing: data\chopin\chp_op31.mid
# [122/295] Processing: data\debussy\debussy_cc_1.mid
# [123/295] Processing: data\debussy\debussy_cc_2.mid
# [124/295] Processing: data\debussy\debussy_cc_3.mid
# [125/295] Processing: data\debussy\debussy_cc_4.mid
# [126/295] Processing: data\debussy\debussy_cc_6.mid
# [127/295] Processing: data\debussy\DEB_CLAI.MID
# [128/295] Processing: data\debussy\deb_menu.mid
# [129/295] Processing: data\debussy\DEB_PASS.MID
# [130/295] Processing: data\debussy\deb_prel.mid
# [131/295] Processing: data\granados\gra_esp_2.mid
# [132/295] Processing: data\granados\gra_esp_3.mid
# [133/295] Processing: data\granados\gra_esp_4.mid
# [134/295] Processing: data\grieg\grieg_album.mid
# [135/295] Processing: data\grieg\grieg_berceuse.mid
# [136/295] Processing: data\grieg\grieg_brooklet.mid
# [137/295] Processing: data\grieg\grieg_butterfly.mid
# [138/295] Processing: data\grieg\grieg_elfentanz.mid
# [139/295] Processing: data\grieg\grieg_halling.mid
# [140/295] Processing: data\grieg\grieg_kobold.mid
# [141/295] Processing: data\grieg\grieg_march.mid
# [142/295] Processing: data\grieg\grieg_once_upon_a_time.mid
# [143/295] Processing: data\grieg\grieg_spring.mid
# [144/295] Processing: data\grieg\grieg_voeglein.mid
# [145/295] Processing: data\grieg\grieg_waechter.mid
# [146/295] Processing: data\grieg\grieg_walzer.mid
# [147/295] Processing: data\grieg\grieg_wanderer.mid
# [148/295] Processing: data\grieg\grieg_wedding.mid
# [149/295] Processing: data\grieg\grieg_zwerge.mid
# [150/295] Processing: data\haydn\haydn_33_1.mid
# [151/295] Processing: data\haydn\haydn_33_2.mid
# [152/295] Processing: data\haydn\haydn_33_3.mid
# [153/295] Processing: data\haydn\haydn_35_1.mid
# [154/295] Processing: data\haydn\haydn_35_2.mid
# [155/295] Processing: data\haydn\haydn_35_3.mid
# [156/295] Processing: data\haydn\haydn_43_1.mid
# [157/295] Processing: data\haydn\haydn_43_2.mid
# [158/295] Processing: data\haydn\haydn_43_3.mid
# [159/295] Processing: data\haydn\haydn_7_1.mid
# [160/295] Processing: data\haydn\haydn_7_2.mid
# [161/295] Processing: data\haydn\haydn_7_3.mid
# [162/295] Processing: data\haydn\haydn_8_1.mid
# [163/295] Processing: data\haydn\haydn_8_2.mid
# [164/295] Processing: data\haydn\haydn_8_3.mid
# [165/295] Processing: data\haydn\haydn_8_4.mid
# [166/295] Processing: data\haydn\haydn_9_1.mid
# [167/295] Processing: data\haydn\haydn_9_2.mid
# [168/295] Processing: data\haydn\haydn_9_3.mid
# [169/295] Processing: data\haydn\hay_40_1.mid
# [170/295] Processing: data\haydn\hay_40_2.mid
# [171/295] Processing: data\liszt\liz_donjuan.mid
# [172/295] Processing: data\liszt\liz_et1.mid
# [173/295] Processing: data\liszt\liz_et2.mid
# [174/295] Processing: data\liszt\liz_et3.mid
# [175/295] Processing: data\liszt\liz_et4.mid
# [176/295] Processing: data\liszt\liz_et5.mid
# [177/295] Processing: data\liszt\liz_et6.mid
# [178/295] Processing: data\liszt\liz_et_trans4.mid
# [179/295] Processing: data\liszt\liz_et_trans5.mid
# [180/295] Processing: data\liszt\liz_et_trans8.mid
# [181/295] Processing: data\liszt\liz_liebestraum.mid
# [182/295] Processing: data\liszt\liz_rhap02.mid
# [183/295] Processing: data\liszt\liz_rhap09.mid
# [184/295] Processing: data\liszt\liz_rhap10.mid
# [185/295] Processing: data\liszt\liz_rhap12.mid
# [186/295] Processing: data\liszt\liz_rhap15.mid
# [187/295] Processing: data\mendelssohn\mendel_op19_1.mid
# [188/295] Processing: data\mendelssohn\mendel_op19_2.mid
# [189/295] Processing: data\mendelssohn\mendel_op19_3.mid
# [190/295] Processing: data\mendelssohn\mendel_op19_4.mid
# [191/295] Processing: data\mendelssohn\mendel_op19_5.mid
# [192/295] Processing: data\mendelssohn\mendel_op19_6.mid
# [193/295] Processing: data\mendelssohn\mendel_op30_1.mid
# [194/295] Processing: data\mendelssohn\mendel_op30_2.mid
# [195/295] Processing: data\mendelssohn\mendel_op30_3.mid
# [196/295] Processing: data\mendelssohn\mendel_op30_4.mid
# [197/295] Processing: data\mendelssohn\mendel_op30_5.mid
# [198/295] Processing: data\mendelssohn\mendel_op53_5.mid
# [199/295] Processing: data\mendelssohn\mendel_op62_3.mid
# [200/295] Processing: data\mendelssohn\mendel_op62_4.mid
# [201/295] Processing: data\mendelssohn\mendel_op62_5.mid
# [202/295] Processing: data\mozart\mz_311_1.mid
# [203/295] Processing: data\mozart\mz_311_2.mid
# [204/295] Processing: data\mozart\mz_311_3.mid
# [205/295] Processing: data\mozart\mz_330_1.mid
# [206/295] Processing: data\mozart\mz_330_2.mid
# [207/295] Processing: data\mozart\mz_330_3.mid
# [208/295] Processing: data\mozart\mz_331_1.mid
# [209/295] Processing: data\mozart\mz_331_2.mid
# [210/295] Processing: data\mozart\mz_331_3.mid
# [211/295] Processing: data\mozart\mz_332_1.mid
# [212/295] Processing: data\mozart\mz_332_2.mid
# [213/295] Processing: data\mozart\mz_332_3.mid
# [214/295] Processing: data\mozart\mz_333_1.mid
# [215/295] Processing: data\mozart\mz_333_2.mid
# [216/295] Processing: data\mozart\mz_333_3.mid
# [217/295] Processing: data\mozart\mz_545_1.mid
# [218/295] Processing: data\mozart\mz_545_2.mid
# [219/295] Processing: data\mozart\mz_545_3.mid
# [220/295] Processing: data\mozart\mz_570_1.mid
# [221/295] Processing: data\mozart\mz_570_2.mid
# [222/295] Processing: data\mozart\mz_570_3.mid
# [223/295] Processing: data\muss\muss_1.mid
# [224/295] Processing: data\muss\muss_2.mid
# [225/295] Processing: data\muss\muss_3.mid
# [226/295] Processing: data\muss\muss_4.mid
# [227/295] Processing: data\muss\muss_5.mid
# [228/295] Processing: data\muss\muss_6.mid
# [229/295] Processing: data\muss\muss_7.mid
# [230/295] Processing: data\muss\muss_8.mid
# [231/295] Processing: data\schubert\schubert_D850_1.mid
# [232/295] Processing: data\schubert\schubert_D850_2.mid
# [233/295] Processing: data\schubert\schubert_D850_3.mid
# [234/295] Processing: data\schubert\schubert_D850_4.mid
# [235/295] Processing: data\schubert\schubert_D935_1.mid
# [236/295] Processing: data\schubert\schubert_D935_2.mid
# [237/295] Processing: data\schubert\schubert_D935_3.mid
# [238/295] Processing: data\schubert\schubert_D935_4.mid
# [239/295] Processing: data\schubert\schub_d760_1.mid
# [240/295] Processing: data\schubert\schub_d760_2.mid
# [241/295] Processing: data\schubert\schub_d760_3.mid
# [242/295] Processing: data\schubert\schub_d760_4.mid
# [243/295] Processing: data\schubert\schub_d960_1.mid
# [244/295] Processing: data\schubert\schub_d960_2.mid
# [245/295] Processing: data\schubert\schub_d960_3.mid
# [246/295] Processing: data\schubert\schub_d960_4.mid
# [247/295] Processing: data\schubert\schuim-1.mid
# [248/295] Processing: data\schubert\schuim-2.mid
# [249/295] Processing: data\schubert\schuim-3.mid
# [250/295] Processing: data\schubert\schuim-4.mid
# [251/295] Processing: data\schubert\schumm-1.mid
# [252/295] Processing: data\schubert\schumm-2.mid
# [253/295] Processing: data\schubert\schumm-3.mid
# [254/295] Processing: data\schubert\schumm-4.mid
# [255/295] Processing: data\schubert\schumm-5.mid
# [256/295] Processing: data\schubert\schumm-6.mid
# [257/295] Processing: data\schubert\schu_143_1.mid
# [258/295] Processing: data\schubert\schu_143_2.mid
# [259/295] Processing: data\schubert\schu_143_3.mid
# [260/295] Processing: data\schumann\schum_abegg.mid
# [261/295] Processing: data\schumann\scn15_1.mid
# [262/295] Processing: data\schumann\scn15_10.mid
# [263/295] Processing: data\schumann\scn15_11.mid
# [264/295] Processing: data\schumann\scn15_12.mid
# [265/295] Processing: data\schumann\scn15_13.mid
# [266/295] Processing: data\schumann\scn15_2.mid
# [267/295] Processing: data\schumann\scn15_3.mid
# [268/295] Processing: data\schumann\scn15_4.mid
# [269/295] Processing: data\schumann\scn15_5.mid
# [270/295] Processing: data\schumann\scn15_6.mid
# [271/295] Processing: data\schumann\scn15_7.mid
# [272/295] Processing: data\schumann\scn15_8.mid
# [273/295] Processing: data\schumann\scn15_9.mid
# [274/295] Processing: data\schumann\scn16_1.mid
# [275/295] Processing: data\schumann\scn16_2.mid
# [276/295] Processing: data\schumann\scn16_3.mid
# [277/295] Processing: data\schumann\scn16_4.mid
# [278/295] Processing: data\schumann\scn16_5.mid
# [279/295] Processing: data\schumann\scn16_6.mid
# [280/295] Processing: data\schumann\scn16_7.mid
# [281/295] Processing: data\schumann\scn16_8.mid
# [282/295] Processing: data\schumann\scn68_10.mid
# [283/295] Processing: data\schumann\scn68_12.mid
# [284/295] Processing: data\tschai\ty_april.mid
# [285/295] Processing: data\tschai\ty_august.mid
# [286/295] Processing: data\tschai\ty_dezember.mid
# [287/295] Processing: data\tschai\ty_februar.mid
# [288/295] Processing: data\tschai\ty_januar.mid
# [289/295] Processing: data\tschai\ty_juli.mid
# [290/295] Processing: data\tschai\ty_juni.mid
# [291/295] Processing: data\tschai\ty_maerz.mid
# [292/295] Processing: data\tschai\ty_mai.mid
# [293/295] Processing: data\tschai\ty_november.mid
# [294/295] Processing: data\tschai\ty_oktober.mid
# [295/295] Processing: data\tschai\ty_september.mid
#
# Processing complete! Total notes collected: 11362
# Epoch 1/50, Loss: 4.8105
# Epoch 2/50, Loss: 4.7188
# Epoch 3/50, Loss: 4.7006
# Epoch 4/50, Loss: 4.7286
# Epoch 5/50, Loss: 4.7003
# Epoch 6/50, Loss: 4.4879
# Epoch 7/50, Loss: 4.4167
# Epoch 8/50, Loss: 4.4045
# Epoch 9/50, Loss: 4.4953
# Epoch 10/50, Loss: 4.3674
# Epoch 11/50, Loss: 4.3262
# Epoch 12/50, Loss: 4.2986
# Epoch 13/50, Loss: 4.2808
# Epoch 14/50, Loss: 4.3636
# Epoch 15/50, Loss: 4.2696
# Epoch 16/50, Loss: 4.1612
# Epoch 17/50, Loss: 4.2439
# Epoch 18/50, Loss: 4.1146
# Epoch 19/50, Loss: 4.0263
# Epoch 20/50, Loss: 4.1249
# Epoch 21/50, Loss: 4.2257
# Epoch 22/50, Loss: 4.1146
# Epoch 23/50, Loss: 4.0485
# Epoch 24/50, Loss: 3.9201
# Epoch 25/50, Loss: 3.8107
# Epoch 26/50, Loss: 3.7471
# Epoch 27/50, Loss: 3.6700
# Epoch 28/50, Loss: 3.5666
# Epoch 29/50, Loss: 3.4160
# Epoch 30/50, Loss: 3.3096
# Epoch 31/50, Loss: 3.2180
# Epoch 32/50, Loss: 4.9684
# Epoch 33/50, Loss: 4.5973
# Epoch 34/50, Loss: 4.4492
# Epoch 35/50, Loss: 4.3476
# Epoch 36/50, Loss: 4.2716
# Epoch 37/50, Loss: 4.1969
# Epoch 38/50, Loss: 4.1743
# Epoch 39/50, Loss: 4.0879
# Epoch 40/50, Loss: 4.0398
# Epoch 41/50, Loss: 3.9689
# Epoch 42/50, Loss: 3.9107
# Epoch 43/50, Loss: 3.8773
# Epoch 44/50, Loss: 3.7818
# Epoch 45/50, Loss: 3.7466
# Epoch 46/50, Loss: 3.6454
# Epoch 47/50, Loss: 3.5453
# Epoch 48/50, Loss: 3.4719
# Epoch 49/50, Loss: 3.4146
# Epoch 50/50, Loss: 3.3556

# %%
import torch
import numpy as np
import pickle
from music21 import instrument, note, stream, chord
# from train import MusicLSTM

# Load mappings
with open("data/mappings.pkl", "rb") as f:
    note_to_int, pitchnames = pickle.load(f)

int_to_note = {num: note for note, num in note_to_int.items()}

# Prepare model
model = MusicLSTM(1, 256, len(pitchnames))
model.load_state_dict(torch.load("model.pth"))
model.eval()

# Generate sequence
sequence_length = 100
start = np.random.randint(0, len(pitchnames)-sequence_length)
pattern = [note_to_int[note] for note in pitchnames[start:start+sequence_length]]

prediction_output = []

for _ in range(200):  # generate 200 notes
    input_seq = torch.tensor(np.reshape(pattern, (1, sequence_length, 1)) / float(len(pitchnames)), dtype=torch.float32)
    prediction = model(input_seq).detach().numpy()
    index = np.argmax(prediction)
    result = int_to_note[index]
    prediction_output.append(result)
    pattern.append(index)
    pattern = pattern[1:]

# Convert to MIDI
offset = 0
output_notes = []

for pattern in prediction_output:
    if ('.' in pattern) or pattern.isdigit():
        notes_in_chord = pattern.split('.')
        notes = [note.Note(int(n)) for n in notes_in_chord]
        for n in notes:
            n.storedInstrument = instrument.Piano()
        new_chord = chord.Chord(notes)
        new_chord.offset = offset
        output_notes.append(new_chord)
    else:
        new_note = note.Note(pattern)
        new_note.offset = offset
        new_note.storedInstrument = instrument.Piano()
        output_notes.append(new_note)

    offset += 0.5

midi_stream = stream.Stream(output_notes)
midi_stream.write('midi', fp='generated_music.mid')
print("Music generated: generated_music.mid")
# Out:
# Music generated: generated_music.mid

# %%
import subprocess
import tkinter as tk
import pygame
import os
from tkinter import filedialog

# Initialize pygame mixer once at the beginning
pygame.mixer.init()

# Configuration paths
fluidsynth_exe = r"C:\Users\mS\Documents\CodeAlpha\Artificial Intelligence\CodeAlpha_AI_tasks\CodeAlpha_Music Generation with AI\fluidsynth-2.4.7-win10-x64\bin\fluidsynth.exe"
sf2_path = r"C:\Users\mS\Documents\CodeAlpha\Artificial Intelligence\CodeAlpha_AI_tasks\CodeAlpha_Music Generation with AI\FluidR3_GM\FluidR3_GM.sf2"
midi_file = "generated_music.mid"
wav_file = "output.wav"

def convert_midi_to_wav():
    """
    Converts MIDI to WAV file without playing it.
    Only performs the conversion and updates status.
    """
    # Stop any currently playing audio first
    pygame.mixer.music.stop()
    pygame.mixer.quit()
    pygame.mixer.init()
    
    if not os.path.exists(midi_file):
        status_label.config(text="Error: MIDI file not found!", fg="red")
        return

    # Ensure no audio is playing during conversion
    status_label.config(text="Converting... Please wait", fg="orange")
    root.update()  # Force UI update to show conversion message

    try:
        # Run conversion with quiet flag to prevent automatic playback
        subprocess.run([
            fluidsynth_exe,
            "-ni",  # Non-interactive mode
            "-q",   # Quiet mode (suppresses output)
            sf2_path,
            midi_file,
            "-F", wav_file,
            "-r", "44100"
        ], check=True)

        if os.path.exists(wav_file):
            status_label.config(text="Conversion complete!\nClick Play to listen", fg="green")
        else:
            status_label.config(text="Error: Conversion failed - no output file", fg="red")
            
    except subprocess.CalledProcessError as e:
        status_label.config(text=f"Conversion error: {e}", fg="red")
    except Exception as e:
        status_label.config(text=f"Unexpected error: {e}", fg="red")

def play_wav():
    """Plays the converted WAV file only if it exists"""
    if not os.path.exists(wav_file):
        status_label.config(text="Error: No WAV file found!\nConvert first", fg="red")
        return
    
    try:
        pygame.mixer.music.load(wav_file)
        pygame.mixer.music.play()
        status_label.config(text="Now playing...", fg="blue")
    except pygame.error as e:
        status_label.config(text=f"Playback error: {e}", fg="red")

def save_wav():
    """Saves the WAV file to user-selected location"""
    if not os.path.exists(wav_file):
        status_label.config(text="Error: No WAV file found!\nConvert first", fg="red")
        return
    
    try:
        save_path = filedialog.asksaveasfilename(
            defaultextension=".wav",
            filetypes=[("WAV files", "*.wav")],
            title="Save WAV File As",
            initialfile="converted_music.wav"
        )
        
        if save_path:
            import shutil
            shutil.copyfile(wav_file, save_path)
            status_label.config(text=f"Saved successfully to:\n{save_path}", fg="green")
    except Exception as e:
        status_label.config(text=f"Save error: {e}", fg="red")

# GUI Setup
root = tk.Tk()
root.title("MIDI to WAV Converter")
root.geometry("400x350")
root.resizable(False, False)
root.configure(bg="#f0f0f0")

# Main frame
main_frame = tk.Frame(root, bg="#f0f0f0")
main_frame.pack(pady=20)

# Buttons
btn_convert = tk.Button(
    main_frame,
    text="Convert MIDI to WAV",
    command=convert_midi_to_wav,
    bg="#4CAF50",
    fg="white",
    font=("Arial", 12, "bold"),
    width=20
)
btn_convert.pack(pady=8)

btn_play = tk.Button(
    main_frame,
    text="Play WAV",
    command=play_wav,
    bg="#2196F3",
    fg="white",
    font=("Arial", 12, "bold"),
    width=20
)
btn_play.pack(pady=8)

btn_save = tk.Button(
    main_frame,
    text="Save WAV File",
    command=save_wav,
    bg="#FF9800",
    fg="white",
    font=("Arial", 12, "bold"),
    width=20
)
btn_save.pack(pady=8)

# Status label
status_label = tk.Label(
    root,
    text="Ready to convert MIDI to WAV",
    bg="#f0f0f0",
    fg="#333333",
    font=("Arial", 11),
    wraplength=350,
    justify="center"
)
status_label.pack(pady=15)

root.mainloop()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import subprocess
import tkinter as tk
from tkinter import ttk, filedialog, messagebox
import pygame
import os
import time

# Initialize pygame mixer
pygame.mixer.init()

# Paths
fluidsynth_exe = r"C:\Users\mS\Documents\CodeAlpha\Artificial Intelligence\CodeAlpha_AI_tasks\CodeAlpha_Music Generation with AI\fluidsynth-2.4.7-win10-x64\bin\fluidsynth.exe"
sf2_path = r"C:\Users\mS\Documents\CodeAlpha\Artificial Intelligence\CodeAlpha_AI_tasks\CodeAlpha_Music Generation with AI\FluidR3_GM\FluidR3_GM.sf2"
midi_file = "generated_music.mid"
wav_file = "output.wav"

class MidiConverterApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Professional MIDI to WAV Converter")
        self.root.geometry("450x300")
        self.root.configure(bg="#f0f0f0")
        self.root.resizable(False, False)
        
        # Styles
        self.style = ttk.Style()
        self.style.configure('TButton', font=('Arial', 10), padding=6)
        self.style.configure('TLabel', background="#f0f0f0", font=('Arial', 10))
        
        # Main Frame
        self.main_frame = ttk.Frame(root, padding="20", style='TFrame')
        self.main_frame.pack(fill=tk.BOTH, expand=True)
        
        # Title
        self.title_label = ttk.Label(
            self.main_frame,
            text="MIDI to WAV Converter",
            font=('Arial', 14, 'bold')
        )
        self.title_label.grid(row=0, column=0, columnspan=2, pady=10)
        
        # Buttons Frame
        self.btn_frame = ttk.Frame(self.main_frame)
        self.btn_frame.grid(row=1, column=0, columnspan=2, pady=15)
        
        # Convert Button
        self.convert_btn = ttk.Button(
            self.btn_frame,
            text="Convert MIDI to WAV",
            command=self.convert_midi_to_wav,
            style='TButton'
        )
        self.convert_btn.pack(side=tk.LEFT, padx=10)
        
        # Play Button
        self.play_btn = ttk.Button(
            self.btn_frame,
            text="Play Music",
            command=self.play_wav,
            style='TButton'
        )
        self.play_btn.pack(side=tk.LEFT, padx=10)
        
        # Save Button
        self.save_btn = ttk.Button(
            self.btn_frame,
            text="Save WAV",
            command=self.save_wav,
            style='TButton'
        )
        self.save_btn.pack(side=tk.LEFT, padx=10)
        
        # Status Frame
        self.status_frame = ttk.Frame(self.main_frame)
        self.status_frame.grid(row=2, column=0, columnspan=2, pady=10)
        
        # Status Label
        self.status_var = tk.StringVar()
        self.status_var.set("Ready")
        self.status_label = ttk.Label(
            self.status_frame,
            textvariable=self.status_var,
            font=('Arial', 10, 'italic')
        )
        self.status_label.pack()
        
        # Progress Bar
        self.progress = ttk.Progressbar(
            self.main_frame,
            orient=tk.HORIZONTAL,
            length=300,
            mode='determinate'
        )
        self.progress.grid(row=3, column=0, columnspan=2, pady=10)
        
        # Info Label
        self.info_label = ttk.Label(
            self.main_frame,
            text=f"MIDI: {midi_file} → WAV: {wav_file}",
            font=('Arial', 8),
            foreground='gray'
        )
        self.info_label.grid(row=4, column=0, columnspan=2, pady=5)
        
    def convert_midi_to_wav(self):
        """Convert MIDI to WAV with progress indication"""
        if not os.path.exists(midi_file):
            self.update_status("Error: MIDI file not found!", "red")
            messagebox.showerror("Error", "MIDI file not found!")
            return
            
        self.update_status("Converting... Please wait", "orange")
        self.progress['value'] = 0
        self.root.update()
        
        try:
            # Simulate progress (since actual conversion is fast)
            for i in range(101):
                self.progress['value'] = i
                self.root.update()
                time.sleep(0.02)
            
            subprocess.run([
                fluidsynth_exe,
                "-ni",
                "-q",
                sf2_path,
                midi_file,
                "-F", wav_file,
                "-r", "44100"
            ], check=True)
            
            self.progress['value'] = 100
            self.update_status("Conversion complete! Ready to play", "green")
            messagebox.showinfo("Success", "MIDI converted to WAV successfully!")
            
        except Exception as e:
            self.update_status(f"Error: {str(e)}", "red")
            messagebox.showerror("Error", f"Conversion failed: {str(e)}")
    
    def play_wav(self):
        """Play WAV file with status updates"""
        if not os.path.exists(wav_file):
            self.update_status("No WAV file found! Convert first.", "red")
            messagebox.showwarning("Warning", "No WAV file found. Please convert first.")
            return
            
        try:
            pygame.mixer.music.stop()
            pygame.mixer.quit()
            pygame.mixer.init()
            
            self.update_status("Playing...", "blue")
            pygame.mixer.music.load(wav_file)
            pygame.mixer.music.play()
            
            # Show duration message
            duration = pygame.mixer.Sound(wav_file).get_length()
            self.root.after(int(duration * 1000), lambda: 
                self.update_status("Playback finished", "green"))
                
        except pygame.error as e:
            self.update_status(f"Playback error: {str(e)}", "red")
            messagebox.showerror("Error", f"Playback failed: {str(e)}")
    
    def save_wav(self):
        """Save WAV file to selected location"""
        if not os.path.exists(wav_file):
            self.update_status("No WAV file to save", "red")
            messagebox.showwarning("Warning", "No WAV file found. Please convert first.")
            return
            
        save_path = filedialog.asksaveasfilename(
            defaultextension=".wav",
            filetypes=[("WAV files", "*.wav"), ("All files", "*.*")],
            title="Save WAV File As"
        )
        
        if save_path:
            try:
                import shutil
                shutil.copy2(wav_file, save_path)
                self.update_status(f"Saved to {os.path.basename(save_path)}", "green")
                messagebox.showinfo("Success", "File saved successfully!")
            except Exception as e:
                self.update_status(f"Save error: {str(e)}", "red")
                messagebox.showerror("Error", f"Failed to save: {str(e)}")
    
    def update_status(self, message, color):
        """Update status label with color coding"""
        self.status_var.set(message)
        if color == "red":
            self.status_label.config(foreground="red")
        elif color == "green":
            self.status_label.config(foreground="green")
        elif color == "blue":
            self.status_label.config(foreground="blue")
        elif color == "orange":
            self.status_label.config(foreground="orange")
        else:
            self.status_label.config(foreground="black")

if __name__ == "__main__":
    root = tk.Tk()
    app = MidiConverterApp(root)
    root.mainloop()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
